# %% [markdown]
# ## Gather Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import wptools
import tweepy
import requests

# %%
#csv file
twitter = pd.read_csv('twitter-archive-enhanced.csv')
#tsv file
url =  "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
r = requests.get(url)
with open('image-predictions.tsv', 'wb') as f:
    f.write(r.content)
image = pd.read_csv('image-predictions.tsv', sep='\t')

# %%
#twitter api
#https://stackoverflow.com/questions/18314749/setup-for-python-tweepy
consumer_key = "x"
consumer_secret = "x"
access_token = "x"
access_token_secret = "x"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
#https://stackoverflow.com/questions/24002536/get-tweepy-search-results-as-json/29006599
#https://stackoverflow.com/questions/4775749/is-there-a-way-to-get-a-tweets-favorite-count
tweet_id = image['tweet_id']
tweets = [] # tweets that can be found by id
dne = [] #tweets that can't be found by id
new_api = tweepy.API(auth, wait_on_rate_limit = True, wait_on_rate_limit_notify = True, parser = tweepy.parsers.JSONParser())

for i in tweet_id:
    try:
        status = new_api.get_status(i)
        faves = status['favorite_count'] #favorites on the tweet
        retweets = status['retweet_count'] #retweets on the tweet
        #datetime = pd.to_dataframe(pg['created_at'])
        tweets.append({'tweet_id':i, 'faves':faves, 'retweets':retweets}) #new dataframe
    except Exception as e:
        dne.append(i)
# Out:
# Rate limit reached. Sleeping for: 738
# Rate limit reached. Sleeping for: 738

# %%
#creating new dataframe
json = pd.DataFrame(tweets, columns = ['tweet_id', 'faves', 'retweets'])
#creating csv file for dataframe
json.to_csv('tweet_json.txt')
new_df = pd.read_csv('tweet_json.txt')
#an extra index was created that is not needed
new_df.drop(columns = ['Unnamed: 0'], inplace=True)
new_df.head()
# Out:
#              tweet_id  faves  retweets
# 0  666020888022790149   2355       449
# 1  666029285002620928    119        41
# 2  666033412701032449    109        39
# 3  666044226329800704    265       124
# 4  666049248165822465     96        40

# %% [markdown]
# ## Access Data

# %%
twitter.sample(3)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1283  708711088997666817                    NaN                  NaN
# 35    885518971528720385                    NaN                  NaN
# 1071  740214038584557568                    NaN                  NaN
#
#                       timestamp  \
# 1283  2016-03-12 17:47:45 +0000
# 35    2017-07-13 15:19:09 +0000
# 1071  2016-06-07 16:09:13 +0000
#
#                                                  source  \
# 1283  <a href="http://twitter.com/download/iphone" r...
# 35    <a href="http://twitter.com/download/iphone" r...
# 1071  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1283  This is Smokey. He really likes tennis balls. ...                  NaN
# 35    I have a new hero and his name is Howard. 14/1...                  NaN
# 1071  This is getting incredibly frustrating. This i...                  NaN
#
# ...

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
#dogs with ratings that have denominator that is larger than the usual
len(twitter[twitter['rating_denominator']>10])
# Out:
# 20

# %%
#dogs with ratings that have numerator that is larger than the normal denominator
len(twitter[twitter['rating_numerator']>21])
# Out:
# 24

# %%
#ratings that don't seem to be in the same scale as the rest of the dogs
len(twitter[(twitter['rating_numerator'] >21)&(twitter['rating_denominator']>10)])
# Out:
# 13

# %%
image.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 938   703631701117943808  https://pbs.twimg.com/media/CcPNS4yW8AAd-Et.jpg
# 1572  795076730285391872  https://pbs.twimg.com/media/CwiuEJmW8AAZnit.jpg
# 974   706901761596989440  https://pbs.twimg.com/media/Cc9rZlBWwAA56Ra.jpg
# 830   693629975228977152  https://pbs.twimg.com/media/CaBEx3SWEAILZpi.jpg
# 1844  838916489579200512  https://pbs.twimg.com/media/C6RkiQZUsAAM4R4.jpg
#
#       img_num            p1   p1_conf  p1_dog              p2   p2_conf  \
# 938         2  window_shade  0.909533   False   window_screen  0.011427
# 1572        2      gas_pump  0.676439   False       harvester  0.049995
# 974         1     wild_boar  0.859499   False             hog  0.128981
# 830         1           pug  0.841987    True  French_bulldog  0.069791
# 1844        2      web_site  0.993651   False         monitor  0.001406
#
#       p2_dog           p3   p3_conf  p3_dog
# ...

# %%
image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
new_df.dtypes
# Out:
# tweet_id    int64
# faves       int64
# retweets    int64
# dtype: object

# %%
new_df.describe()
# Out:
#            tweet_id          faves      retweets
# count  2.059000e+03    2059.000000   2059.000000
# mean   7.378345e+17    7809.789218   2512.055367
# std    6.758411e+16   11805.533098   4389.400703
# min    6.660209e+17       0.000000     11.000000
# 25%    6.762505e+17    1484.000000    537.500000
# 50%    7.113067e+17    3440.000000   1186.000000
# 75%    7.928986e+17    9729.500000   2885.500000
# max    8.924206e+17  152563.000000  75497.000000

# %%
#very strange that there are some tweets that have no favorites but have retweets
new_df['faves'].nsmallest(7)
# Out:
# 94      0
# 95      0
# 1036    0
# 1296    0
# 1313    0
# 1328    0
# 1331    0
# Name: faves, dtype: int64

# %%
new_df['retweets'].nsmallest(7)
# Out:
# 16      11
# 36      18
# 1891    19
# 94      27
# 130     29
# 28      31
# 95      31
# Name: retweets, dtype: int64

# %% [markdown]
# # Quailty Issues
#
# **Twitter dataframe**
# <br>
# 1 = Only need original tweets
# <br>
# 2 = Can delete unnessacy columns
# <br>
# 3 = Some dogs either don't have names or have random words or letters
# <br>
# 4 = There are some rows with oddly large numerator and denominator values
# <br>
# 5 = A lot of 'None' values in whole dataframe
# <br>
# **Image dataframe**
# <br>
# 6 = Make convert the prediction confidence columns to percentages (multiply them by 100)
# <br>
# 7 = The img_num column is not needed
# <br>
# **New_df dataframe**
# <br>
# 8 = There are some tweets with no favorites
#
# # Tidiness Issues
# 1 = Merge all datasets toegther
# <br>
# 2 = Combine the numerator and denominator to make one rating
# <br>
# 2 = Combine the doggo, floofer, pupper, and puppo into one column

# %% [markdown]
# ## Cleaning Data

# %%
#copy dataframes
twitter_clean = twitter.copy()
image_clean = image.copy()
df_clean = new_df.copy()

# %%
twitter_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
image_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
df_clean.head()
# Out:
#              tweet_id  faves  retweets
# 0  666020888022790149   2355       449
# 1  666029285002620928    119        41
# 2  666033412701032449    109        39
# 3  666044226329800704    265       124
# 4  666049248165822465     96        40

# %% [markdown]
# ## Quality
# **Define: 1. Delete all of the retweets so only have the orginal ratings (twitter_clean)**

# %%
twitter_clean.shape[0]
# Out:
# 2356

# %% [markdown]
# **Code:**

# %%
#only want the null rows in retweeted_status_id
twitter_clean = twitter_clean[pd.isnull(twitter_clean['retweeted_status_id'])]

# %% [markdown]
# **Test:**

# %%
twitter_clean.shape[0]
# Out:
# 2175

# %% [markdown]
# **Define: 2. Delete columns that are not needed (twitter_clean)**

# %% [markdown]
# **Code:**

# %%
twitter_clean.drop(['in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'], axis = 1, inplace = True)

# %% [markdown]
# **Test:**

# %%
twitter_clean.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None
# 1                  10    Tilly  None    None   None  None

# %% [markdown]
# **Define: 3. Some dogs either don't have names or have random words or letters (twitter_clean)**

# %%
twitter_clean[twitter_clean['name'].apply(len)<3]
# Out:
#                 tweet_id                  timestamp  \
# 56    881536004380872706  2017-07-02 15:32:16 +0000
# 393   825876512159186944  2017-01-30 01:21:19 +0000
# 449   819004803107983360  2017-01-11 02:15:36 +0000
# 553   804026241225523202  2016-11-30 18:16:08 +0000
# 649   792913359805018113  2016-10-31 02:17:31 +0000
# 679   789137962068021249  2016-10-20 16:15:26 +0000
# 775   776201521193218049  2016-09-14 23:30:38 +0000
# 801   772581559778025472  2016-09-04 23:46:12 +0000
# 820   770414278348247044  2016-08-30 00:14:12 +0000
# 852   765395769549590528  2016-08-16 03:52:26 +0000
# 876   761004547850530816  2016-08-04 01:03:17 +0000
# 978   749996283729883136  2016-07-04 16:00:22 +0000
# 1002  747885874273214464  2016-06-28 20:14:22 +0000
# 1004  747816857231626240  2016-06-28 15:40:07 +0000
# 1017  746872823977771008  2016-06-26 01:08:52 +0000
# 1025  746369468511756288  2016-06-24 15:48:42 +0000
# 1049  743222593470234624  2016-06-15 23:24:09 +0000
# ...

# %% [markdown]
# **Code:**

# %%
twitter_clean['name'].replace(['a', 'an', 'my', 'by', 'O'], 'None', inplace=True)
len(twitter_clean[twitter_clean['name'].apply(len)<3])
# Out:
# 11

# %% [markdown]
# **Test:**

# %%
twitter_clean[twitter_clean['name'].apply(len)<3]
# Out:
#                 tweet_id                  timestamp  \
# 393   825876512159186944  2017-01-30 01:21:19 +0000
# 449   819004803107983360  2017-01-11 02:15:36 +0000
# 553   804026241225523202  2016-11-30 18:16:08 +0000
# 679   789137962068021249  2016-10-20 16:15:26 +0000
# 820   770414278348247044  2016-08-30 00:14:12 +0000
# 876   761004547850530816  2016-08-04 01:03:17 +0000
# 978   749996283729883136  2016-07-04 16:00:22 +0000
# 1683  681694085539872773  2015-12-29 04:31:49 +0000
# 1988  672834301050937345  2015-12-04 17:46:12 +0000
# 2041  671542985629241344  2015-12-01 04:14:59 +0000
# 2219  668496999348633600  2015-11-22 18:31:19 +0000
#
#                                                  source  \
# 393   <a href="http://twitter.com/download/iphone" r...
# 449   <a href="http://twitter.com/download/iphone" r...
# 553   <a href="http://twitter.com/download/iphone" r...
# 679   <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# **Define: 4. There are some rows with oddly large numerator and denominator values (twitter_clean)**

# %%
twitter_clean[twitter_clean['rating_denominator'] > 10]
# Out:
#                 tweet_id                  timestamp  \
# 342   832088576586297345  2017-02-16 04:45:50 +0000
# 433   820690176645140481  2017-01-15 17:52:40 +0000
# 902   758467244762497024  2016-07-28 01:00:57 +0000
# 1068  740373189193256964  2016-06-08 02:41:38 +0000
# 1120  731156023742988288  2016-05-13 16:15:54 +0000
# 1165  722974582966214656  2016-04-21 02:25:47 +0000
# 1202  716439118184652801  2016-04-03 01:36:11 +0000
# 1228  713900603437621249  2016-03-27 01:29:02 +0000
# 1254  710658690886586372  2016-03-18 02:46:49 +0000
# 1274  709198395643068416  2016-03-14 02:04:08 +0000
# 1351  704054845121142784  2016-02-28 21:25:30 +0000
# 1433  697463031882764288  2016-02-10 16:51:59 +0000
# 1598  686035780142297088  2016-01-10 04:04:10 +0000
# 1634  684225744407494656  2016-01-05 04:11:44 +0000
# 1635  684222868335505415  2016-01-05 04:00:18 +0000
# 1662  682962037429899265  2016-01-01 16:30:13 +0000
# 1663  682808988178739200  2016-01-01 06:22:03 +0000
# ...

# %% [markdown]
# **Code:**

# %%
#I think there was an error where the 11 denominator is supposed to be a 10
twitter_clean['rating_denominator'].replace(11, 10, inplace=True)

#some tweets don't have expanded urls and I don't think they are suuposed to be here
twitter_clean = twitter_clean[twitter_clean['expanded_urls'].notna()]

# %% [markdown]
# **Test:**

# %%
#will be converting into ratios later and then reanalyzing
twitter_clean[twitter_clean['rating_denominator'] > 10]
# Out:
#                 tweet_id                  timestamp  \
# 433   820690176645140481  2017-01-15 17:52:40 +0000
# 902   758467244762497024  2016-07-28 01:00:57 +0000
# 1120  731156023742988288  2016-05-13 16:15:54 +0000
# 1165  722974582966214656  2016-04-21 02:25:47 +0000
# 1202  716439118184652801  2016-04-03 01:36:11 +0000
# 1228  713900603437621249  2016-03-27 01:29:02 +0000
# 1254  710658690886586372  2016-03-18 02:46:49 +0000
# 1274  709198395643068416  2016-03-14 02:04:08 +0000
# 1351  704054845121142784  2016-02-28 21:25:30 +0000
# 1433  697463031882764288  2016-02-10 16:51:59 +0000
# 1634  684225744407494656  2016-01-05 04:11:44 +0000
# 1635  684222868335505415  2016-01-05 04:00:18 +0000
# 1779  677716515794329600  2015-12-18 05:06:23 +0000
# 1843  675853064436391936  2015-12-13 01:41:41 +0000
#
#                                                  source  \
# 433   <a href="http://twitter.com/download/iphone" r...
# 902   <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# **Define: 5. Replace all of the 'None' with 'Nan'(twitter_clean)**

# %%
twitter_clean.sample(6)
# Out:
#                 tweet_id                  timestamp  \
# 1003  747844099428986880  2016-06-28 17:28:22 +0000
# 640   793241302385262592  2016-11-01 00:00:38 +0000
# 2051  671488513339211776  2015-12-01 00:38:31 +0000
# 1368  702539513671897089  2016-02-24 17:04:07 +0000
# 2069  671134062904504320  2015-11-30 01:10:04 +0000
# 1872  675146535592706048  2015-12-11 02:54:12 +0000
#
#                                                  source  \
# 1003  <a href="http://twitter.com/download/iphone" r...
# 640   <a href="http://twitter.com/download/iphone" r...
# 2051  <a href="http://twitter.com/download/iphone" r...
# 1368  <a href="http://twitter.com/download/iphone" r...
# 2069  <a href="http://twitter.com/download/iphone" r...
# 1872  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 1003  This is Huxley. He's pumped for #BarkWeek. Eve...
# 640   This is Tucker. He's out here bustin h*ckin gh...
# ...

# %% [markdown]
# **Code:**

# %%
twitter_clean.replace('None', np.nan, inplace=True)

# %% [markdown]
# **Test:**

# %%
twitter_clean.sample(6)
# Out:
#                 tweet_id                  timestamp  \
# 978   749996283729883136  2016-07-04 16:00:22 +0000
# 1811  676819651066732545  2015-12-15 17:42:34 +0000
# 851   765669560888528897  2016-08-16 22:00:23 +0000
# 2123  670385711116361728  2015-11-27 23:36:23 +0000
# 2013  672231046314901505  2015-12-03 01:49:05 +0000
# 1094  736736130620620800  2016-05-29 01:49:16 +0000
#
#                                                  source  \
# 978   <a href="https://about.twitter.com/products/tw...
# 1811  <a href="http://twitter.com/download/iphone" r...
# 851   <a href="http://twitter.com/download/iphone" r...
# 2123  <a href="http://twitter.com/download/iphone" r...
# 2013  <a href="http://twitter.com/download/iphone" r...
# 1094  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 978   This is Bo. He emanates happiness. 12/10 I cou...
# 1811  Watch out Airbud. This pupper is also good at ...
# ...

# %% [markdown]
# **Define: 6. Make convert the prediction confidence columns to percentages (multiply them by 100) (image_clean)**

# %%
image_clean.sample(4)
# Out:
#                 tweet_id                                          jpg_url  \
# 1309  754011816964026368  https://pbs.twimg.com/media/CnbJuPoXEAAjcVF.jpg
# 800   691416866452082688  https://pbs.twimg.com/media/CZhn-QAWwAASQan.jpg
# 727   686377065986265092  https://pbs.twimg.com/media/CYaAS2kUoAINkye.jpg
# 861   697242256848379904  https://pbs.twimg.com/media/Ca0aIR9WcAAHiPy.jpg
#
#       img_num                p1   p1_conf  p1_dog             p2   p2_conf  \
# 1309        1    French_bulldog  0.600985    True    Boston_bull  0.273176
# 800         1  Lakeland_terrier  0.530104    True  Irish_terrier  0.197314
# 727         1   German_shepherd  0.830816    True       Leonberg  0.076325
# 861         1          grey_fox  0.236031   False    Siamese_cat  0.165791
#
#       p2_dog          p3   p3_conf  p3_dog
# 1309    True       boxer  0.056772    True
# 800     True    Airedale  0.082515    True
# 727     True  bloodhound  0.037449    True
# 861    False  Eskimo_dog  0.063533    True

# %% [markdown]
# **Code:**

# %%
image_clean['p1_conf'] = image_clean['p1_conf']*100
image_clean['p2_conf'] = image_clean['p2_conf']*100
image_clean['p3_conf'] = image_clean['p3_conf']*100

# %% [markdown]
# **Test:**

# %%
image_clean.sample(4)
# Out:
#                 tweet_id                                          jpg_url  \
# 155   668815180734689280  https://pbs.twimg.com/media/CUgb21RXIAAlff7.jpg
# 1385  766008592277377025  https://pbs.twimg.com/media/CqFouXOXYAAYpzG.jpg
# 422   674051556661161984  https://pbs.twimg.com/media/CVq2UHwWEAAduMw.jpg
# 1280  750132105863102464  https://pbs.twimg.com/media/CmkBKuwWgAAamOI.jpg
#
#       img_num                      p1  p1_conf  p1_dog                 p2  \
# 155         1                 redbone  46.1172    True  Italian_greyhound
# 1385        1  Welsh_springer_spaniel  72.8153    True             basset
# 422         1                Shih-Tzu  17.9777    True             badger
# 1280        1              toy_poodle  47.8018    True   miniature_poodle
#
#       p2_conf  p2_dog                  p3   p3_conf  p3_dog
# 155   27.0733    True  miniature_pinscher  10.97520    True
# 1385  10.3842    True    Brittany_spaniel   6.24143    True
# ...

# %% [markdown]
# **Define: 7. There is only one jpg_url so img_num column can be deleted (image_clean)**

# %%
#even when the img_num is greater than 1 there is still only one jpg url
len(image_clean[image_clean['img_num'] == 4]) #max is 4
# Out:
# 31

# %% [markdown]
# **Code:**

# %%
image_clean['img_num'].nlargest(3)
# Out:
# 144     4
# 779     4
# 1024    4
# Name: img_num, dtype: int64

# %%
print(image_clean.loc[779])
# Out:
# tweet_id                                 689905486972461056
# jpg_url     https://pbs.twimg.com/media/CZMJYCRVAAE35Wk.jpg
# img_num                                                   4
# p1                                               Pomeranian
# p1_conf                                             94.3331
# p1_dog                                                 True
# p2                                        Shetland_sheepdog
# p2_conf                                             2.36751
# p2_dog                                                 True
# p3                                                     chow
# p3_conf                                            0.716495
# p3_dog                                                 True
# Name: 779, dtype: object

# %%
del image_clean['img_num']

# %% [markdown]
# **Test:**

# %%
image_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#                        p1  p1_conf  p1_dog                  p2   p2_conf  \
# 0  Welsh_springer_spaniel  46.5074    True              collie  15.66650
# 1                 redbone  50.6826    True  miniature_pinscher   7.41917
# 2         German_shepherd  59.6461    True            malinois  13.85840
# 3     Rhodesian_ridgeback  40.8143    True             redbone  36.06870
# 4      miniature_pinscher  56.0311    True          Rottweiler  24.36820
#
#    p2_dog                   p3   p3_conf  p3_dog
# 0    True    Shetland_sheepdog   6.14285    True
# ...

# %% [markdown]
# **Define: 8. There are some tweets with no favorites (df_clean)**

# %%
#usually tweets have a lot more favorites than retweets
df_clean[df_clean['faves']>0].sum()
# Out:
# tweet_id    4396844578529211630
# faves                  16080356
# retweets                4741031
# dtype: int64

# %% [markdown]
# **Code:**

# %%
#proportion of favorites/retweets
16082671/4741465
# Out:
# 3.391920218750956

# %%
#making the favorites the normal rate compared to retweets where favorites = 0
df_clean['faves'] = np.where(df_clean['faves'] == 0, (df_clean['retweets']*3.39), df_clean['faves'])

# %% [markdown]
# **Test:**

# %%
df_clean['faves'].nsmallest(5)
# Out:
# 1891    64.41
# 16      69.00
# 94      91.53
# 18      94.00
# 36      94.00
# Name: faves, dtype: float64

# %% [markdown]
# ## Tidiness
# **Define: 1 . Merging all three dataframes together**

# %% [markdown]
# **Code:**

# %%
df_clean = pd.merge(left = twitter_clean, right = df_clean, how = 'inner', right_on = 'tweet_id', left_on = 'tweet_id')
df_clean.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name doggo floofer pupper puppo    faves  retweets
# 0                  10  Phineas   NaN     NaN    NaN   NaN  35390.0      7477
# 1                  10    Tilly   NaN     NaN    NaN   NaN  30638.0      5549

# %%
df_clean = pd.merge(left = df_clean, right = image_clean, how = 'inner', right_on = 'tweet_id', left_on = 'tweet_id')

# %% [markdown]
# **Test:**

# %%
df_clean.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name doggo floofer   ...    \
# 0                  10  Phineas   NaN     NaN   ...
# 1                  10    Tilly   NaN     NaN   ...
#
#                                            jpg_url         p1   p1_conf  \
# ...

# %% [markdown]
# **Define: 2. Create only one rating column by taking the rating_numerator/rating_denominator**

# %% [markdown]
# **Code:**

# %%
rating = df_clean['rating_numerator']/df_clean['rating_denominator']
rating
# Out:
# 0       1.3
# 1       1.3
# 2       1.2
# 3       1.3
# 4       1.2
# 5       1.3
# 6       1.3
# 7       1.3
# 8       1.3
# 9       1.4
# 10      1.3
# 11      1.3
# 12      1.3
# 13      1.2
# 14      1.3
# 15      1.3
# 16      1.2
# 17      1.3
# 18      1.3
# 19      1.2
# 20      1.3
# 21      1.4
# 22      1.3
# 23      1.3
# 24      1.2
# 25      1.3
# 26      1.3
# 27      1.3
# 28      1.2
# 29      1.3
#        ...
# 1957    0.2
# 1958    0.7
# 1959    0.9
# 1960    1.1
# 1961    0.6
# 1962    0.8
# 1963    1.0
# 1964    0.9
# 1965    0.3
# 1966    0.5
# 1967    1.1
# 1968    1.0
# 1969    0.1
# 1970    1.1
# 1971    0.8
# 1972    0.9
# 1973    0.6
# 1974    1.0
# 1975    0.9
# 1976    1.0
# 1977    0.8
# 1978    0.9
# 1979    1.0
# 1980    0.2
# 1981    1.0
# 1982    0.5
# 1983    0.6
# 1984    0.9
# 1985    0.7
# 1986    0.8
# Length: 1987, dtype: float64

# %%
del df_clean['rating_numerator']
del df_clean['rating_denominator']
df_clean['rating'] = rating
df_clean['rating']
# Out:
# 0       1.3
# 1       1.3
# 2       1.2
# 3       1.3
# 4       1.2
# 5       1.3
# 6       1.3
# 7       1.3
# 8       1.3
# 9       1.4
# 10      1.3
# 11      1.3
# 12      1.3
# 13      1.2
# 14      1.3
# 15      1.3
# 16      1.2
# 17      1.3
# 18      1.3
# 19      1.2
# 20      1.3
# 21      1.4
# 22      1.3
# 23      1.3
# 24      1.2
# 25      1.3
# 26      1.3
# 27      1.3
# 28      1.2
# 29      1.3
#        ...
# 1957    0.2
# 1958    0.7
# 1959    0.9
# 1960    1.1
# 1961    0.6
# 1962    0.8
# 1963    1.0
# 1964    0.9
# 1965    0.3
# 1966    0.5
# 1967    1.1
# 1968    1.0
# 1969    0.1
# 1970    1.1
# 1971    0.8
# 1972    0.9
# 1973    0.6
# 1974    1.0
# 1975    0.9
# 1976    1.0
# 1977    0.8
# 1978    0.9
# 1979    1.0
# 1980    0.2
# 1981    1.0
# 1982    0.5
# 1983    0.6
# 1984    0.9
# 1985    0.7
# 1986    0.8
# Name: rating, Length: 1987, dtype: float64

# %%
#some of these rating do not proportionally make sense, so deleting those rows
df_clean['rating'].nlargest(7)
# Out:
# 720     177.600000
# 1711     42.000000
# 499       7.500000
# 381       3.428571
# 548       2.700000
# 1368      2.600000
# 9         1.400000
# Name: rating, dtype: float64

# %%
#dropping rows with ratings greater than 20/10
df_clean.drop(df_clean[df_clean['rating'] > 2].index, inplace = True)
df_clean['rating'].nlargest(5)
# Out:
# 9     1.4
# 21    1.4
# 36    1.4
# 49    1.4
# 64    1.4
# Name: rating, dtype: float64

# %% [markdown]
# **Test:**

# %%
df_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# **Define: 3. Combine the doggo, floofer, pupper, and puppo into one column**

# %% [markdown]
# **Code:**

# %%
#https://stackoverflow.com/questions/41449555/pandas-combine-two-columns-with-null-values
dogtionary = df_clean['doggo']
df_clean['dogtionary'] = dogtionary
multiple = df_clean['doggo']+df_clean['pupper']+df_clean['puppo']+df_clean['floofer']
df_clean['multiple'] = multiple

# %%
df_clean['dogtionary'].fillna(df_clean['floofer'], inplace=True)
df_clean['dogtionary'].fillna(df_clean['pupper'], inplace=True)
df_clean['dogtionary'].fillna(df_clean['puppo'], inplace=True)

# %%
del df_clean['doggo']
del df_clean['floofer']
del df_clean['pupper']
del df_clean['puppo']

# %% [markdown]
# **Test:**

# %%
df_clean.head(4)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
#
#                                        expanded_urls     name    faves  \
# 0  https://twitter.com/dog_rates/status/892420643...  Phineas  35390.0
# ...

# %%
df_clean['multiple'].notnull().sum()
# Out:
# 0

# %% [markdown]
# ## Store

# %%
df_clean.to_csv('twitter_archive_master.csv')

# %% [markdown]
# ## Analyze

# %% [markdown]
# **1. It is a lot easier to collect information from twitter than I thought. The only issue I had was that some tweets did not have favorites on them.
# After doing a quick google search, favorites were created when twitter was so the timestamp has nothing to do with it. Those tweets could for some reason
# not have any favorites or some security settings might have not allowed it to happen or for me to extract that informtion. For exmaple
# if someone is on private and they favorited that tweet.**

# %% [markdown]
# **2. Even though I did clean the dataframe a lot there is more to clean. The timestamp has "+0000" after every value and can be put into several columns for more assesment. The source column has the whole link in html so if you print out the row it is not clickable. The text column usually has the name in the third word of the 'text' column and if it is a random word then it is a retweet.**

# %% [markdown]
# **3. The ratings and retweets have a positive coorelation with each other. However the highest rating is a 1.4 but 1.3 rating actually have more retweets. The lowest rating given is a 0/10 and the highest is a 14/10.**

# %% [markdown]
# **4. Pupper is the worst dogtionary term in terms of retweets and ratings overall with the lowest average mean and medians. All categories except for pupper has an average rating of 12/10 but pupper has an 11/10.**

# %% [markdown]
# ## Visualization

# %%
vis = df_clean.plot.scatter(x = 'rating', y = 'retweets', c = 'DarkBlue', title = "Reweets vs. Ratings")

# %% [markdown]
# **Just as I would aspect the retweets increase with an increase of rating.**

# %%
doggo = df_clean[df_clean['dogtionary'] == "doggo"]
floofer = df_clean[df_clean['dogtionary'] == "floofer"]
pupper = df_clean[df_clean['dogtionary'] == "pupper"]
puppo = df_clean[df_clean['dogtionary'] == "puppo"]

# %%
len(doggo)
# Out:
# 73

# %%
len(floofer)
# Out:
# 7

# %%
len(pupper)
# Out:
# 202

# %%
len(puppo)
# Out:
# 22

# %%
doggo['rating'].median(), doggo['rating'].mean()
# Out:
# (1.2, 1.1767123287671231)

# %%
floofer['rating'].median(), floofer['rating'].mean()
# Out:
# (1.2, 1.2)

# %%
pupper['rating'].median(), pupper['rating'].mean()
# Out:
# (1.1000000000000001, 1.0633663366336634)

# %%
puppo['rating'].median(), puppo['rating'].mean()
# Out:
# (1.2, 1.2000000000000002)

# %%
doggo['retweets'].median(), doggo['retweets'].mean()
# Out:
# (2650.0, 6118.9863013698632)

# %%
floofer['retweets'].median(), floofer['retweets'].mean()
# Out:
# (2794.0, 4226.0)

# %%
pupper['retweets'].median(), pupper['retweets'].mean()
# Out:
# (1018.5, 2035.3217821782177)

# %%
puppo['retweets'].median(), puppo['retweets'].mean()
# Out:
# (2672.0, 5660.545454545455)

# %%
d = doggo.plot.scatter(x = 'rating', y = 'retweets', c = 'Purple', title = "Doggo Reweets vs. Ratings")

# %%
f = floofer.plot.scatter(x = 'rating', y = 'retweets', c = 'Green', title = "Floofer Reweets vs. Ratings")

# %%
pr = pupper.plot.scatter(x = 'rating', y = 'retweets', c = 'Blue', title = "Pupper Reweets vs. Ratings")

# %%
pu = puppo.plot.scatter(x = 'rating', y = 'retweets', c = 'Red', title = "Puppo Reweets vs. Ratings")
